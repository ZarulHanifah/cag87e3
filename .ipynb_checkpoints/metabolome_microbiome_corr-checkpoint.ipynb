# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import ipywidgets as widgets
import plotly.express as px
from IPython.display import clear_output

# %%
meta = pd.read_csv("input_folder/metadata48.tsv", sep="\t", index_col=0)
crit1 = meta["Group"] != "S"
crit2 = meta["Hour"] != 0

meta = meta.loc[crit1 & crit2, :]
meta["Hour"] = meta["Hour"].astype(int)
meta["GH"] = meta["Group"] + meta["Hour"].astype(str)

meta.index = [re.sub("H$", "", i) for i in meta.index]
# meta.head()

# %%
def read_met_table(met_table_path):
    met_table = pd.read_csv(met_table_path, sep="\t", index_col=0)
    met_table.set_index("Compound", inplace=True)
    met_table = met_table.loc[:, [c for c in met_table.columns if "-" in c]]
    met_table = met_table.T
    met_table.index = [re.sub("H$", "", i) for i in met_table.index]
    return met_table

met_table_path = "input_folder/MT.tsv"

met_table = read_met_table(met_table_path)
met_table.head()
# Out:
# Compound  Lysinium  Histidine   Arginine  \
# C1-12        0.000       0.00      0.000
# C2-12        0.000       0.00      0.000
# C3-12        0.000       0.00      0.000
# C4-12        0.000       0.00      0.000
# C1-24     8847.402   85714.73  16104.868
#
# Compound  N-[2-(1H-imidazol-5-yl)ethyl]propan-2-amine   Cholinum  \
# C1-12                                             0.0   56617.67
# C2-12                                             0.0  119624.65
# C3-12                                             0.0   94939.44
# C4-12                                             0.0  138813.56
# C1-24                                             0.0  358585.90
#
# Compound  4-aminobutanoate   Glutamin   Carnitin  \
# C1-12                 0.00      0.000      0.000
# C2-12                 0.00      0.000      0.000
# C3-12                 0.00      0.000      0.000
# C4-12                 0.00      0.000      0.000
# C1-24             44031.76  40629.223  23342.062
#
# Compound  2-aminoethyl methyl phosphate  Choline alfoscerate  ...  \
# C1-12                         82257.700                  0.0  ...
# C2-12                        126540.780                  0.0  ...
# C3-12                        115416.710                  0.0  ...
# C4-12                        102493.625                  0.0  ...
# C1-24                         97686.110                  0.0  ...
#
# Compound  Didecanoylphosphatidic acid   Ethyl stearate  \
# C1-12                             0.0        49796.004
# C2-12                             0.0        77644.580
# C3-12                             0.0        57205.227
# C4-12                             0.0        40322.850
# C1-24                             0.0       489627.560
#
# Compound  1-tridecanoyl-2-octadecanoyl-glycero-3-phosphate  \
# C1-12                                            17007.129
# C2-12                                            27740.426
# C3-12                                            20746.023
# C4-12                                            15235.298
# C1-24                                            52943.530
#
# Compound  Dilinoleoylphosphatidylcholine  Tetracosanamide  \
# C1-12                          99149.266              0.0
# C2-12                         259318.840              0.0
# C3-12                         224820.030              0.0
# C4-12                         153608.380              0.0
# C1-24                         114910.610              0.0
#
# Compound  DL-alpha-Tocopherol  2-Ethyl-6-methylcyclohexa-2,5-diene-1,4-dione  \
# C1-12               1061486.6                                      29454.232
# C2-12               1840373.0                                      53727.777
# C3-12               1823423.6                                      50516.350
# C4-12               1783805.5                                      53272.450
# C1-24               1047916.7                                      28016.350
#
# Compound  Campest-4-en-3-one  \
# C1-12              64451.870
# C2-12              83185.910
# C3-12             134909.880
# C4-12              93861.625
# C1-24              36525.816
#
# Compound  2,5,7,8-tetramethyl-2-[(E)-4,8,12-trimethyltridec-3-enyl]-3,4-dihydrochromen-1-ium-6-ol  \
# C1-12                                             1239112.0
# C2-12                                             1664786.2
# C3-12                                             1880470.4
# C4-12                                             1897372.4
# C1-24                                             1086071.6
#
# Compound  Ethylene dioleamide
# C1-12                     0.0
# C2-12                     0.0
# C3-12                     0.0
# C4-12                     0.0
# C1-24                     0.0
#
# [5 rows x 389 columns]

# %%
from statsmodels.formula.api import mixedlm
from statsmodels.tools.sm_exceptions import ConvergenceWarning
import warnings


results = []
warnings.simplefilter("ignore", ConvergenceWarning)  # optional: ignore convergence warnings

for met in met_table.columns:
    df = meta.copy()
    df["Concentration"] = met_table[met]
    df["Group"] = df["Group"].astype("category")
    # df["Hour"] = df["Hour"].astype("category")
    df["Replicate"] = df["Replicate"].astype("category")

    try:
        model = mixedlm("Concentration ~ Group * Hour", data=df, groups=df["Replicate"])
        result = model.fit()
        pvals = result.pvalues
        results.append({
            "Metabolite": met,
            "p_Group": pvals.get("Group[T.M]", float("nan")),
            "p_Hour": pvals.get("Hour", float("nan")),  # you can handle this better later
            "p_Interaction": pvals.get("Group[T.M]:Hour", float("nan"))  # adjust for all timepoints if needed
        })
    except Exception as e:
        print(f"Failed for {met}: {e}")

m = pd.DataFrame(results)
# Out:
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1556: RuntimeWarning: divide by zero encountered in log
#   likeval -= (self.n_totobs - self.k_fe) * np.log(qf) / 2.
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1796: RuntimeWarning: invalid value encountered in divide
#   score_re += 0.5 * fac * rvavr[0:self.k_re2] / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/numpy/linalg/_linalg.py:2325: RuntimeWarning: invalid value encountered in slogdet
#   sign, logdet = _umath_linalg.slogdet(a, signature=signature)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2005: RuntimeWarning: divide by zero encountered in divide
#   hess_fe -= fac * xtvix / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2006: RuntimeWarning: invalid value encountered in divide
#   hess_re = hess_re - 0.5 * fac * (D/rvir - np.outer(B, B) / rvir**2)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2007: RuntimeWarning: invalid value encountered in divide
#   hess_fere = -fac * hess_fere / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1556: RuntimeWarning: divide by zero encountered in log
#   likeval -= (self.n_totobs - self.k_fe) * np.log(qf) / 2.
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1796: RuntimeWarning: invalid value encountered in divide
#   score_re += 0.5 * fac * rvavr[0:self.k_re2] / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/numpy/linalg/_linalg.py:2325: RuntimeWarning: invalid value encountered in slogdet
#   sign, logdet = _umath_linalg.slogdet(a, signature=signature)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2005: RuntimeWarning: divide by zero encountered in divide
#   hess_fe -= fac * xtvix / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2006: RuntimeWarning: invalid value encountered in divide
#   hess_re = hess_re - 0.5 * fac * (D/rvir - np.outer(B, B) / rvir**2)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2007: RuntimeWarning: invalid value encountered in divide
#   hess_fere = -fac * hess_fere / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1556: RuntimeWarning: divide by zero encountered in log
#   likeval -= (self.n_totobs - self.k_fe) * np.log(qf) / 2.
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1796: RuntimeWarning: invalid value encountered in divide
#   score_re += 0.5 * fac * rvavr[0:self.k_re2] / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/numpy/linalg/_linalg.py:2325: RuntimeWarning: invalid value encountered in slogdet
#   sign, logdet = _umath_linalg.slogdet(a, signature=signature)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2005: RuntimeWarning: divide by zero encountered in divide
#   hess_fe -= fac * xtvix / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2006: RuntimeWarning: invalid value encountered in divide
#   hess_re = hess_re - 0.5 * fac * (D/rvir - np.outer(B, B) / rvir**2)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2007: RuntimeWarning: invalid value encountered in divide
#   hess_fere = -fac * hess_fere / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1556: RuntimeWarning: divide by zero encountered in log
#   likeval -= (self.n_totobs - self.k_fe) * np.log(qf) / 2.
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1796: RuntimeWarning: invalid value encountered in divide
#   score_re += 0.5 * fac * rvavr[0:self.k_re2] / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/numpy/linalg/_linalg.py:2325: RuntimeWarning: invalid value encountered in slogdet
#   sign, logdet = _umath_linalg.slogdet(a, signature=signature)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2005: RuntimeWarning: divide by zero encountered in divide
#   hess_fe -= fac * xtvix / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2006: RuntimeWarning: invalid value encountered in divide
#   hess_re = hess_re - 0.5 * fac * (D/rvir - np.outer(B, B) / rvir**2)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2007: RuntimeWarning: invalid value encountered in divide
#   hess_fere = -fac * hess_fere / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1556: RuntimeWarning: divide by zero encountered in log
#   likeval -= (self.n_totobs - self.k_fe) * np.log(qf) / 2.
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1796: RuntimeWarning: invalid value encountered in divide
#   score_re += 0.5 * fac * rvavr[0:self.k_re2] / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/numpy/linalg/_linalg.py:2325: RuntimeWarning: invalid value encountered in slogdet
#   sign, logdet = _umath_linalg.slogdet(a, signature=signature)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2005: RuntimeWarning: divide by zero encountered in divide
#   hess_fe -= fac * xtvix / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2006: RuntimeWarning: invalid value encountered in divide
#   hess_re = hess_re - 0.5 * fac * (D/rvir - np.outer(B, B) / rvir**2)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2007: RuntimeWarning: invalid value encountered in divide
#   hess_fere = -fac * hess_fere / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1556: RuntimeWarning: divide by zero encountered in log
#   likeval -= (self.n_totobs - self.k_fe) * np.log(qf) / 2.
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1796: RuntimeWarning: invalid value encountered in divide
#   score_re += 0.5 * fac * rvavr[0:self.k_re2] / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/numpy/linalg/_linalg.py:2325: RuntimeWarning: invalid value encountered in slogdet
#   sign, logdet = _umath_linalg.slogdet(a, signature=signature)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2005: RuntimeWarning: divide by zero encountered in divide
#   hess_fe -= fac * xtvix / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2006: RuntimeWarning: invalid value encountered in divide
#   hess_re = hess_re - 0.5 * fac * (D/rvir - np.outer(B, B) / rvir**2)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2007: RuntimeWarning: invalid value encountered in divide
#   hess_fere = -fac * hess_fere / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1556: RuntimeWarning: divide by zero encountered in log
#   likeval -= (self.n_totobs - self.k_fe) * np.log(qf) / 2.
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1796: RuntimeWarning: invalid value encountered in divide
#   score_re += 0.5 * fac * rvavr[0:self.k_re2] / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/numpy/linalg/_linalg.py:2325: RuntimeWarning: invalid value encountered in slogdet
#   sign, logdet = _umath_linalg.slogdet(a, signature=signature)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2005: RuntimeWarning: divide by zero encountered in divide
#   hess_fe -= fac * xtvix / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2006: RuntimeWarning: invalid value encountered in divide
#   hess_re = hess_re - 0.5 * fac * (D/rvir - np.outer(B, B) / rvir**2)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2007: RuntimeWarning: invalid value encountered in divide
#   hess_fere = -fac * hess_fere / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1556: RuntimeWarning: divide by zero encountered in log
#   likeval -= (self.n_totobs - self.k_fe) * np.log(qf) / 2.
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1796: RuntimeWarning: invalid value encountered in divide
#   score_re += 0.5 * fac * rvavr[0:self.k_re2] / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/numpy/linalg/_linalg.py:2325: RuntimeWarning: invalid value encountered in slogdet
#   sign, logdet = _umath_linalg.slogdet(a, signature=signature)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2005: RuntimeWarning: divide by zero encountered in divide
#   hess_fe -= fac * xtvix / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2006: RuntimeWarning: invalid value encountered in divide
#   hess_re = hess_re - 0.5 * fac * (D/rvir - np.outer(B, B) / rvir**2)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2007: RuntimeWarning: invalid value encountered in divide
#   hess_fere = -fac * hess_fere / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1556: RuntimeWarning: divide by zero encountered in log
#   likeval -= (self.n_totobs - self.k_fe) * np.log(qf) / 2.
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1796: RuntimeWarning: invalid value encountered in divide
#   score_re += 0.5 * fac * rvavr[0:self.k_re2] / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/numpy/linalg/_linalg.py:2325: RuntimeWarning: invalid value encountered in slogdet
#   sign, logdet = _umath_linalg.slogdet(a, signature=signature)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2005: RuntimeWarning: divide by zero encountered in divide
#   hess_fe -= fac * xtvix / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2006: RuntimeWarning: invalid value encountered in divide
#   hess_re = hess_re - 0.5 * fac * (D/rvir - np.outer(B, B) / rvir**2)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2007: RuntimeWarning: invalid value encountered in divide
#   hess_fere = -fac * hess_fere / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1556: RuntimeWarning: divide by zero encountered in log
#   likeval -= (self.n_totobs - self.k_fe) * np.log(qf) / 2.
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1796: RuntimeWarning: invalid value encountered in divide
#   score_re += 0.5 * fac * rvavr[0:self.k_re2] / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/numpy/linalg/_linalg.py:2325: RuntimeWarning: invalid value encountered in slogdet
#   sign, logdet = _umath_linalg.slogdet(a, signature=signature)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2005: RuntimeWarning: divide by zero encountered in divide
#   hess_fe -= fac * xtvix / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2006: RuntimeWarning: invalid value encountered in divide
#   hess_re = hess_re - 0.5 * fac * (D/rvir - np.outer(B, B) / rvir**2)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2007: RuntimeWarning: invalid value encountered in divide
#   hess_fere = -fac * hess_fere / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1556: RuntimeWarning: divide by zero encountered in log
#   likeval -= (self.n_totobs - self.k_fe) * np.log(qf) / 2.
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1796: RuntimeWarning: invalid value encountered in divide
#   score_re += 0.5 * fac * rvavr[0:self.k_re2] / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/numpy/linalg/_linalg.py:2325: RuntimeWarning: invalid value encountered in slogdet
#   sign, logdet = _umath_linalg.slogdet(a, signature=signature)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2005: RuntimeWarning: divide by zero encountered in divide
#   hess_fe -= fac * xtvix / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2006: RuntimeWarning: invalid value encountered in divide
#   hess_re = hess_re - 0.5 * fac * (D/rvir - np.outer(B, B) / rvir**2)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2007: RuntimeWarning: invalid value encountered in divide
#   hess_fere = -fac * hess_fere / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1556: RuntimeWarning: divide by zero encountered in log
#   likeval -= (self.n_totobs - self.k_fe) * np.log(qf) / 2.
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1796: RuntimeWarning: invalid value encountered in divide
#   score_re += 0.5 * fac * rvavr[0:self.k_re2] / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/numpy/linalg/_linalg.py:2325: RuntimeWarning: invalid value encountered in slogdet
#   sign, logdet = _umath_linalg.slogdet(a, signature=signature)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2005: RuntimeWarning: divide by zero encountered in divide
#   hess_fe -= fac * xtvix / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2006: RuntimeWarning: invalid value encountered in divide
#   hess_re = hess_re - 0.5 * fac * (D/rvir - np.outer(B, B) / rvir**2)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2007: RuntimeWarning: invalid value encountered in divide
#   hess_fere = -fac * hess_fere / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1556: RuntimeWarning: divide by zero encountered in log
#   likeval -= (self.n_totobs - self.k_fe) * np.log(qf) / 2.
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1796: RuntimeWarning: invalid value encountered in divide
#   score_re += 0.5 * fac * rvavr[0:self.k_re2] / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/numpy/linalg/_linalg.py:2325: RuntimeWarning: invalid value encountered in slogdet
#   sign, logdet = _umath_linalg.slogdet(a, signature=signature)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2005: RuntimeWarning: divide by zero encountered in divide
#   hess_fe -= fac * xtvix / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2006: RuntimeWarning: invalid value encountered in divide
#   hess_re = hess_re - 0.5 * fac * (D/rvir - np.outer(B, B) / rvir**2)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2007: RuntimeWarning: invalid value encountered in divide
#   hess_fere = -fac * hess_fere / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1556: RuntimeWarning: divide by zero encountered in log
#   likeval -= (self.n_totobs - self.k_fe) * np.log(qf) / 2.
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:1796: RuntimeWarning: invalid value encountered in divide
#   score_re += 0.5 * fac * rvavr[0:self.k_re2] / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/numpy/linalg/_linalg.py:2325: RuntimeWarning: invalid value encountered in slogdet
#   sign, logdet = _umath_linalg.slogdet(a, signature=signature)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2005: RuntimeWarning: divide by zero encountered in divide
#   hess_fe -= fac * xtvix / rvir
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2006: RuntimeWarning: invalid value encountered in divide
#   hess_re = hess_re - 0.5 * fac * (D/rvir - np.outer(B, B) / rvir**2)
# /home/ahbui/Zarul/Software/miniconda3/lib/python3.12/site-packages/statsmodels/regression/mixed_linear_model.py:2007: RuntimeWarning: invalid value encountered in divide
#   hess_fere = -fac * hess_fere / rvir
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_50434/562130582.py in ?()
#       7 warnings.simplefilter("ignore", ConvergenceWarning)  # optional: ignore convergence warnings
#       8
#       9 for met in met_table.columns:
#      10     df = meta.copy()
# ---> 11     df["Concentration"] = met_table[met]
#      12     df["Group"] = df["Group"].astype("category")
#      13     # df["Hour"] = df["Hour"].astype("category")
#      14     df["Replicate"] = df["Replicate"].astype("category")
#
# ~/Zarul/Software/miniconda3/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4297             self._setitem_frame(key, value)
#    4298         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
# -> 4301             self._set_item_frame_value(key, value)
#    4302         elif (
#    4303             is_list_like(value)
#    4304             and not self.columns.is_unique
#
# ~/Zarul/Software/miniconda3/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4455
#    4456             return self.isetitem(locs, value)
#    4457
#    4458         if len(value.columns) > 1:
# -> 4459             raise ValueError(
#    4460                 "Cannot set a DataFrame with multiple columns to the single "
#    4461                 f"column {key}"
#    4462             )
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column Concentration

# %%
from collections import Counter
Counter(met_table.columns)
# Out:
# Counter({'Dibutyl 3-oxopentanedioate': 2,
#          'Lysinium': 1,
#          'Histidine': 1,
#          'Arginine': 1,
#          'N-[2-(1H-imidazol-5-yl)ethyl]propan-2-amine': 1,
#          'Cholinum': 1,
#          '4-aminobutanoate': 1,
#          'Glutamin': 1,
#          'Carnitin': 1,
#          '2-aminoethyl methyl phosphate': 1,
#          'Choline alfoscerate': 1,
#          'Threonin': 1,
#          'L-citrulline': 1,
#          'Glutamat': 1,
#          'Ononitol': 1,
#          'Trigonelline': 1,
#          '5-Hydroxymethylfurfural': 1,
#          'n5-acetyl-l-ornithine': 1,
#          'Adenine': 1,
#          '2,1-Benzoxaborole, 4-fluoro-1,3-dihydro-1-hydroxy-': 1,
#          'Imidazole-4-acrylic acid': 1,
#          'O-acetyl-L-carnitine': 1,
#          'Pyridoxine (vitamin B6)': 1,
#          'Adenine arabinoside': 1,
#          'D-pipecolate': 1,
#          'Uracil': 1,
#          'piperidine-2,6-dicarboxylate': 1,
#          'Nicotinate': 1,
#          'DL-methionine': 1,
#          'Xanthine': 1,
#          'Pidolate': 1,
#          'Hypoxanthine': 1,
#          'Isonicotinamide': 1,
#          'Tyrosine': 1,
#          'Phenacylamine': 1,
#          'Coumarate': 1,
#          'Tyramine ': 1,
#          '4-Vinylphenol': 1,
#          'Isoleucine': 1,
#          'Thymine': 1,
#          'L-Norleucine': 1,
#          'Adipo-2,6-lactam': 1,
#          'H-Glu-Tyr-OH': 1,
#          'Indoline': 1,
#          'DL-Phenylalanine (Sabiden)': 1,
#          'Vitamin B5': 1,
#          '3-hydroxyanthranilic acid': 1,
#          'Phenethylamine': 1,
#          'Styrene': 1,
#          'Vitamin L2': 1,
#          '3-indoleacrylate': 1,
#          'DL-Tryptophan': 1,
#          'Indole-3-carboxaldehyde': 1,
#          'Indole': 1,
#          '3-ethenyl-1H-indole': 1,
#          'Isoleucylproline': 1,
#          'Methyl L-leucinate': 1,
#          '6-(2-oxopyrrolidin-1-yl)hexanoic acid': 1,
#          'Kaempferol 3-(3Rha-glucosylrutinoside)': 1,
#          '(4S)-4-amino-5-[[(1S)-1-carboxy-2-phenylethyl]amino]-5-oxopentanoic acid': 1,
#          'Phenylalanylproline': 1,
#          'Isovalerylcarnitine': 1,
#          'Leucyl-Isoleucine ': 1,
#          '3-methyl-2-[(3-methylfuran-2-carbonyl)amino]pentanoic acid': 1,
#          'Ethyl 2-amino-4-methylpentanoate': 1,
#          'Glycitin': 1,
#          'Daidzin': 1,
#          'Tetrahydroharman-3-carboxylic acid': 1,
#          'Tetramethylpyrazine': 1,
#          'L-phenylalanyl-L-leucine': 1,
#          'Jasmonate': 1,
#          '2-(4-aminoanilino)propanoate': 1,
#          '|A-(Methylamino)-3-pyridinebutanoic Acid': 1,
#          'Malonyldaidzin': 1,
#          'Malonylglycitin': 1,
#          'Genistin': 1,
#          'Homoplantaginin': 1,
#          '(2E,6E)-5,8-dihydroxydodeca-2,6-dienoic acid': 1,
#          '2-Vinylquinoline': 1,
#          "6''-O-acetyldaidzin": 1,
#          'N-Acetylisoleucine': 1,
#          'Coumarin': 1,
#          ' 4-Hydroxy Cinnamic Acid': 1,
#          'Malonylgenistin': 1,
#          '1-benzyl-4-prop-2-ynylpiperazine': 1,
#          "4,4'-diaminoazobenzene": 1,
#          '1-methyl-N-(pyridin-2-ylmethyl)benzimidazol-2-amine': 1,
#          'N-acetyl-L-phenylalanine': 1,
#          "6''-O-acetylgenistin": 1,
#          '4-Dimethylamino-L-phenylalanine': 1,
#          '(1-(3-Oxo-2-aza-spiro(4.5)dec-2-ylmethyl)-cyclohexyl)-acetic acid': 1,
#          'Trimethyl-pyrazine': 1,
#          ' O-octanoylcarnitine': 1,
#          'Daidzein': 1,
#          'N-(5-{[1,3-dioxo-2-(4-pyridylcarbonylamino)benzo[c]azolidin-5-yl]carbonyl}-1,3-dioxobenzo[c]azolin-2-yl)-4-pyridylcarboxamide': 1,
#          '2,3-dimethyl-5-isopropylpyrazine': 1,
#          'alfa-Cyperone': 1,
#          'Glycetein': 1,
#          '5-Ethyl-2,3-dimethylpyrazine': 1,
#          'Maltol acetate': 1,
#          '9-(nonanoylamino)nonanoic Acid': 1,
#          'Genistein': 1,
#          'N-(3-hydroxy-4-methoxyphenyl)-3-nitro-4-(trifluoromethoxy)benzenesulfonamide': 1,
#          '2-[[2-[(2-amino-3-methylpentanoyl)amino]-3-hydroxybutanoyl]amino]-3-hydroxypropanoic acid': 1,
#          'Pratensein': 1,
#          'Sedanolide': 1,
#          'Soyasaponin V': 1,
#          'N-[bis(4-dimethylaminophenyl)methylene]aniline': 1,
#          '(8R,9S,10R,13S,14S,17S)-17-hydroxy-13-methyl-2,4,7,8,9,10,11,12,14,15,16,17-dodecahydro-1H-cyclopenta[a]phenanthren-3-one': 1,
#          'Soyasaponin I': 1,
#          '(2S)-N-[(2S)-5-(diaminomethylideneamino)-1-oxopentan-2-yl]-1-[(2R)-pyrrolidine-2-carbonyl]pyrrolidine-2-carboxamide': 1,
#          '[(2S,3S,5R)-3-azido-5-(5-methyl-2,4-dioxopyrimidin-1-yl)oxolan-2-yl]methyl (4-nitrophenyl)methyl phenyl phosphate': 1,
#          'Biochanin B': 1,
#          'N-[(3R)-7-bromo-1-methyl-2-oxo-3,4-dihydro-1,5-naphthyridin-3-yl]-methylboronamidic acid': 1,
#          'Oxamic acid derivative, 1': 1,
#          'Soyasaponin II': 1,
#          'Somatotropin (6-13)': 1,
#          'Oleanolic aldehyde': 1,
#          '[(2R,4aR,6aR,6aS,6bR,8aR,9S,10S,12aR,14bS)-10-acetyloxy-9-(acetyloxymethyl)-2,4a,6a,6b,9,12a-hexamethyl-4-oxo-3,5,6,6a,7,8,8a,10,11,12,13,14b-dodecahydro-1H-picen-2-yl]methyl acetate': 1,
#          '1-cyclohexylbenzimidazole-2-thiol': 1,
#          'Soyasaponin III': 1,
#          "2,2'-[(Dodecylimino)bis(ethyleneoxy)]diethan": 1,
#          '4-[N-benzyl-C-[4-(dimethylamino)phenyl]carbonimidoyl]-N,N-dimethylaniline': 1,
#          'Soyasaponin IV': 1,
#          'N-[3-[3-aminopropyl(methyl)amino]propyl]octadec-9-enamide': 1,
#          'methyl 7-[(1R,2S,3R)-3-hydroxy-2-[(3S)-3-hydroxyoct-1-ynyl]-5-oxocyclopentyl]heptanoate': 1,
#          '2-(4-Methoxyphenyl)-2H-1,2,3-benzotriazol-5-ylamine': 1,
#          'Pyoctanin': 1,
#          '7-O-Ethyldaidzein': 1,
#          '5-butoxy-3-butoxycarbonyl-3-hydroxy-5-oxopentanoic acid': 1,
#          'Betulonaldehyde': 1,
#          '2-(2,4-Dinitroanilino)-2-(hydroxymethyl)propane-1,3-diol': 1,
#          'Dehydrophytosphingosine': 1,
#          'Octadeca-8,10,12,14,16-pentaenoic acid': 1,
#          'alpha-12,13-DiHODE': 1,
#          'Anthraquinone': 1,
#          'N-(1-hydroxy-3-phenylpropan-2-yl)-15-pyridin-1-ium-1-N-(1-hydroxy-3-phenylpropan-2-yl)-15-pyridin-1-ium-1-ylpentadecanamide': 1,
#          'N-[2-[[(Z)-heptadec-12-en-10-ynyl]-methylamino]ethyl]-N-methylacetamide': 1,
#          '16-[bis(2-hydroxyethyl)amino]hexadecan-1-ol': 1,
#          '7-Ethoxy-4′-methoxyisoflavone': 1,
#          '1,3-Bis(4-nitrophenoxy)propane': 1,
#          ' Phytosphingosine': 1,
#          '9-hydroxy-10E,12Z,15Z-octadecatrienoic acid': 1,
#          '6-amino-2-[[(9Z,12Z)-octadeca-9,12-dienoyl]amino]hexanoic Acid': 1,
#          'Aformosin': 1,
#          '8-(4-methoxybenzoyl)oxyoctyl 4-methoxybenzoate': 1,
#          'Sphinganine': 1,
#          '3-(3-methoxyphenoxy)-4-oxochromen-7-yl methylsulfonate': 1,
#          'Isoleukotoxin': 1,
#          '9,12-Octadecadienamide, N-[2-(dimethylamino)ethyl]-, (9Z,12Z)-': 1,
#          'N-palmitoyl histidine': 1,
#          'N-palmitoyl lysine': 1,
#          'Linoleamidopropyl Dimethylamine': 1,
#          '2-[[(2S)-2-amino-6-(tert-butylamino)hexanoyl]amino]-6-(tert-butylamino)hexanoic acid': 1,
#          '1-18:3-lysoPE': 1,
#          '1-18:3-lysoPC': 1,
#          'N-Palmitoyl-L-arginine': 1,
#          'N-(3-aminopropyl)hexadecanamide': 1,
#          'N-oleoyl histidine': 1,
#          'Palmitoylputrescine': 1,
#          ' LysoPE(16:1(9Z)/0:0)': 1,
#          '8,11,14-Eicosatrienoic acid': 1,
#          '2,3-dihydroxypropyl octadeca-6,9,12,15-tetraenoate': 1,
#          'N-Hexadecyl diethanolamine': 1,
#          'N-(3-aminopropyl)octadec-9-enamide': 1,
#          '9-Octadecenamide, N-[3-(methylamino)propyl]-, (Z)-': 1,
#          'Methyl (2S,6R)-7-hydroxy-2,6-bis[(2-methylpropan-2-yl)oxycarbonylamino]heptanoate': 1,
#          'Linoleamide ': 1,
#          'tert-butyl N-[1-[[1-(2-hydroxyphenyl)-2-(4-methoxyanilino)-2-oxoethyl]-methylamino]-4-methyl-1-oxopentan-2-yl]carbamate': 1,
#          'LysoPE(18:2(9Z,12Z) (Lysophosphatidylethanolamine)': 1,
#          ' LysoPC(0:0/18:2(9Z,12Z))': 1,
#          '2-[[2-[[6-amino-2-[(2-amino-3-phenylpropanoyl)amino]hexanoyl]amino]-3-hydroxybutanoyl]amino]-3-(4-hydroxyphenyl)propanoic acid': 1,
#          'Ethyl 3-oxo-2-pentylcyclopentane-1-carboxylate': 1,
#          '(10Z,14E,16E)-10,14,16-Octadecatrien-12-ynoic acid': 1,
#          'Palmitoylethanolamide': 1,
#          '1-(9Z,12Z-octadecadienoyl)-glycero-3-phosphoserine': 1,
#          'n-Stearoyl lysine': 1,
#          'n-Stearoyl histidine': 1,
#          'n-Linolenoyl glutamic acid': 1,
#          '12,15-Octadecadiynoic acid': 1,
#          '9-OxoOTrE': 1,
#          '11,15-Octadecadiynoic acid': 1,
#          'LysoPE(16:0/0:0)': 1,
#          '2-[[2-[[2-(2,6-diaminohexanoylamino)-3-hydroxypropanoyl]amino]-3-methylpentanoyl]amino]-4-methylpentanoic acid': 1,
#          'LysoPC(16:0/0:0)': 1,
#          '7-oxooctadecanoate': 1,
#          'N-(3-Aminopropyl)stearamide': 1,
#          '(5Z,9E)-6,10,14-trimethylpentadeca-5,9,13-trien-1-yne': 1,
#          'Farnesyl acetone': 1,
#          '13-Octadecen-2-one, 1,1,1-trifluoro-, (13Z)-': 1,
#          '(9E,11E)-Octadecadienoic acid': 1,
#          'N-(2-hydroxy-1-methylethyl)-9-octadecenamide': 1,
#          'N-(2-hydroxyethyl)nonadecanamide': 1,
#          '4-acetamido-N,N-dibutyl-5-chloro-2-methoxybenzamide': 1,
#          '2-[[2-[(2-Azaniumyl-4-methylpentanoyl)amino]-3-methylbutanoyl]amino]-4-methylpentanoate': 1,
#          'Alpha-Linolenoyl ethanolamide': 1,
#          ' Linoleic acid': 1,
#          '9,12-Octadecadiynoicacid': 1,
#          'Dodecadienoic acid isobutylamide': 1,
#          'LysoPE(18:1(9Z)/0:0)': 1,
#          'Lysolecithin': 1,
#          'Octadeca-10,12-dienoic acid': 1,
#          'N-(9Z,12Z,15Z)-octadecatrienoylglycinate': 1,
#          'N-(.alpha.-Linolenoyl) Tyrosine': 1,
#          '2-[2-[2-[2-[2-(decylamino)-2-oxoethoxy]ethoxy]ethoxy]ethoxy]acetic acid': 1,
#          'Tributyl Citrate': 1,
#          '4-[[(6Z,9Z,12Z)-octadeca-6,9,12-trienoyl]amino]butanoic acid': 1,
#          '13-oxooctadeca-9,11-dienoic acid': 1,
#          ' LysoPI(16:0/0:0)': 1,
#          'Methyl 7-(3-nonyloxiran-2-yl)heptanoate': 1,
#          'N-heptyl-4,6-dimorpholin-4-yl-1,3,5-triazin-2-amine': 1,
#          'Glutamic acid lineolamide': 1,
#          '1-oleoyl-sn-glycero-3-phosphoserine': 1,
#          '12,13-EpOME': 1,
#          'LPG(18:2(9Z,12Z)/0:0)': 1,
#          'Linoleic acid amide': 1,
#          'tert-butyl N-[(2R)-4-methyl-1-[[(2S)-1-(methylamino)-1-oxo-3-prop-2-enoxypropan-2-yl]amino]-1-oxopentan-2-yl]carbamate': 1,
#          'N-palmitoyl glutamine': 1,
#          '(2S)-1-[(2S)-2-(hexadecanoylamino)-3-hydroxypropanoyl]pyrrolidine-2-carboxamide': 1,
#          'Linoleyl aldehyde': 1,
#          '1-Monolinolenin': 1,
#          '9-Octadecen-16-ynoic acid': 1,
#          'CPA(18:2(9Z,12Z)/0:0)': 1,
#          'Cis-8,11,14,17-Eicosatetraenoic acid': 1,
#          'Linoleoyl ethanolamide (Linoleamide MEA)': 1,
#          'N-oleoyl glutamine': 1,
#          'Docosatetraenoyl Ethanolamide': 1,
#          'Palmitoleamide': 1,
#          '2-O-acetyl-1-O-hexadecyl-sn-glycero-3-phosphocholine': 1,
#          'n-Linoleoyl tyrosine': 1,
#          'Palmitoylglutamic acid': 1,
#          'Linoleoyl glycine': 1,
#          'Octadeca-9,12,15-trien-2-one': 1,
#          ' N-Linoleoyl GABA': 1,
#          '9-Octadecen-17-ynoicacid': 1,
#          'n-palmitoylserine': 1,
#          'Stearoyl lysophosphatidylethanolamine': 1,
#          ' LysoPC(18:0/0:0)': 1,
#          'Oleoyl glutamic acid': 1,
#          '34,8,12-Trimethyltrideca-3,7,11-trien-2-one': 1,
#          '15-Hexadecynoic acid': 1,
#          'Linoleoyl sarcosine': 1,
#          'N-prop-2-enylnonanamide': 1,
#          '2,4-tetradecadienoic acid isobutyl amide': 1,
#          '(11E)-1-azacyclotridec-11-en-2-one': 1,
#          'Azacyclododecan-2-one': 1,
#          'MG(16:1(9Z)': 1,
#          'N-Oleoyl-L-Serine': 1,
#          'N-palmitoyl threonine': 1,
#          'methyl 2-[2-[(2-methylpropan-2-yl)oxycarbonylamino]pentanoylamino]pentanoate': 1,
#          'Glycidyl linoleate': 1,
#          'N-palmitoyl tyrosine': 1,
#          '1-Linoleoyl-rac-glycerol': 1,
#          'Palmitoylglycine': 1,
#          'Anandamide (18:4, n-3)': 1,
#          'Alpha-linolenic acid (alpha-LA)': 1,
#          '(1-(tert-Butoxycarbonyl)-4-(ethoxycarbonyl)-1H-indol-2-yl)boronic acid': 1,
#          'N-Palmitoyl GABA': 1,
#          'Actinonin': 1,
#          'N-oleoyl threonine': 1,
#          'Linolenyl alcohol': 1,
#          '3,3,4-trimethylcyclodecyne': 1,
#          '4-[(E)-4-(4-ethenylcyclohexyl)but-1-enyl]cyclohexan-1-one': 1,
#          ' Oleoyl ethanolamide': 1,
#          'N-oleoyl tyrosine': 1,
#          '(4E,8E)-5,9,13-trimethyltetradeca-4,8,12-trien-2-one': 1,
#          'Linoleoyl proline': 1,
#          'Elmiric acid': 1,
#          '3-(1H-indol-3-yl)-2-(octadec-2-ynoylamino)propanoic acid': 1,
#          'N-oleoyl GABA': 1,
#          'Margaroylglycine': 1,
#          '3-[4-(Pentadec-4-enylamino)phenyl]prop-2-ynoic acid': 1,
#          '2-Dodecyl-1H-quinolin-4-one': 1,
#          'N-(nonylideneamino)nonanamide': 1,
#          'N-linoleoyl valine': 1,
#          'Anandamide (20:3, n-3)': 1,
#          '1-Hexadecyn-6-one': 1,
#          'Palmitoleate': 1,
#          'N-Oleoylsarcosine': 1,
#          'Glycidyl palmitate': 1,
#          'Monopalmitin': 1,
#          '(2S)-2-[[(2S,3S)-2-[[(2S)-2-amino-3-cyclohexylpropanoyl]amino]-3-methylpentanoyl]amino]-3-phenylpropanoic acid': 1,
#          'N2,N2-Dimethyl-N6-oleoyl-DL-lysine': 1,
#          'n-linoleoyl leucine': 1,
#          'Oleamide': 1,
#          'Tridecadienoic acid': 1,
#          '13-Tetradecynoic acid': 1,
#          '4-(2,2,4-Trimethylcyclohex-3-enyl)but-3-en-2-one': 1,
#          'Dodecadienoic acid': 1,
#          'MG(18:1(9Z)/0:0/0:0)': 1,
#          '(5E,9E)-6,10,14-trimethylpentadeca-1,5,9,13-tetraene': 1,
#          "N-Methyl-N'-[10-(6-oxo-3-phenylpyridazin-1(6H)-yl)decyl]urea": 1,
#          'N-palmitoyl methionine': 1,
#          '15-oxo-11Z,13E-eicosadienoate': 1,
#          'Oleoyl methyl beta-alanine': 1,
#          'Heptadecanamide': 1,
#          'n-Oleoyl serinol': 1,
#          'Glycidol oleate': 1,
#          'Oleic acid': 1,
#          'N-(4-hydroxyphenethyl)oleamide': 1,
#          'Icosatrienoic acid': 1,
#          'N-Stearoyl Threonine': 1,
#          'N-Oleoyl methionine': 1,
#          '8Z-heptadecenoic acid': 1,
#          'Octadecanamide': 1,
#          'N-(2-hydroxyethyl)octadecanamide': 1,
#          '(2R)-3-methyl-2-[[(Z)-octadec-9-enoyl]amino]butanoic acid': 1,
#          'N-Stearoylglycine': 1,
#          'N-Stearoyl GABA': 1,
#          'Eruric acid': 1,
#          'N-palmitoyl phenylalanine': 1,
#          'Anandamide (20:2, n-6)': 1,
#          'Oleoyl Ethyl Amide': 1,
#          'N-palmitoyl leucine': 1,
#          'N-(3-(Decylamino)propyl)-D-gluconamide': 1,
#          '(E,2S)-2-hexyl-5-hydroxyhexadec-3-enoic acid': 1,
#          'PC(18:2(9Z,12Z)/18:3(9Z,12Z,15Z))': 1,
#          'N-oleoyl phenylalanine': 1,
#          'Stearoyl sarcosine': 1,
#          'tert-butyl N-[1-[[1-[(1-cyclohexyl-3-oxopropan-2-yl)amino]-1-oxopropan-2-yl]amino]-1-oxo-3-phenylpropan-2-yl]carbamate': 1,
#          'Gama-Tocotrienol': 1,
#          'Methyl retinoate': 1,
#          'N-oleoyl isoleucine (Isoleucine)': 1,
#          'N-(octylideneamino)dodecanamide': 1,
#          '2-[(3S,6R,9S,12S,15R)-3-[(2S)-butan-2-yl]-6,15-bis(2-methylpropyl)-2,5,8,11,14,17-hexaoxo-12-propan-2-yl-19-undecyl-1-oxa-4,7,10,13,16-pentazacyclononadec-9-yl]acetic acid': 1,
#          'Ethyl dihomo-gamma-linolenate ': 1,
#          'Methyl alpha-Eleostearate': 1,
#          '1-(2-chlorobenzyl)-N-[3-(morpholin-4-yl)propyl]piperidine-4-carboxamide': 1,
#          'Dihydro-alpha-ionone': 1,
#          '8-tridecenoic acid': 1,
#          'gamma-Dodecalactone': 1,
#          'Myristoleic acid': 1,
#          '10-(3-octyloxiran-2-yl)decanoic acid': 1,
#          'TG(18:3(9Z,12Z,15Z)': 1,
#          ' N-acylsphingosine': 1,
#          'cis-11-Eicosenamide': 1,
#          '1-Stearoyl-rac-glycerol': 1,
#          'Glycidol stearate': 1,
#          '(5Z,8Z,11Z,14Z)-icosatetraen-1-ol': 1,
#          'Icosadienoic acid': 1,
#          '(5E,9E,13E,17E)-6,10,14,18,22-pentamethyltricosa-5,9,13,17,21-pentaen-1-yne': 1,
#          'N-(2-Phenylethyl)hexadecanamide': 1,
#          '(9E)-tetradeca-9,11-dienoic acid': 1,
#          'Ethyl linolenate': 1,
#          '1-eicosenoyl-glycerol': 1,
#          'N-ethyloctadecanamide': 1,
#          'Ercalcitriol': 1,
#          'Methyl lineoleate': 1,
#          'Erucamide': 1,
#          'N-stearoyl phenylalanine': 1,
#          'N-Stearoyl-L-leucine': 1,
#          'Palmitic acid': 1,
#          'Linoleyl alcohol': 1,
#          'Ethyl palmitoleate': 1,
#          '1-tridecanoyl-sn-glycero-3-phosphocholine': 1,
#          'Phthalic acid': 1,
#          '8,11,14-Eicosatrien-1-ol': 1,
#          'Gondoic Acid': 1,
#          'Icosanamide': 1,
#          'ethyl undec-9-enoate': 1,
#          'Linolelaidic acid (Mandenol)': 1,
#          'but-2-ynyl dodecanoate': 1,
#          '2-but-1-en-3-ynyl-1,3,3-trimethylcyclohexene': 1,
#          '(Z)-2,3-di(icosyl)but-2-enediamide': 1,
#          'Ethyl pentadecanoate': 1,
#          'N-phenethyloctadecanamide': 1,
#          'PE(18:3(9Z,12Z,15Z)': 1,
#          'Methyl oleate': 1,
#          'Lauric anhydride': 1,
#          'Docosanoyl Ethanolamide': 1,
#          'Stearic acid': 1,
#          'Ethyl oleate': 1,
#          'PC(34:1) (Phosphatidylcholine)': 1,
#          'Lecithin': 1,
#          ' Docosanamide': 1,
#          '(Z)-tetracos-15-enamide': 1,
#          'N-(hexadecanoyl)-1beta-glucosyl-4E,14Z-sphingadienine': 1,
#          '1-(4-Methoxyphenyl)icosane-1,3-dione': 1,
#          'Didecanoylphosphatidic acid': 1,
#          ' Ethyl stearate': 1,
#          '1-tridecanoyl-2-octadecanoyl-glycero-3-phosphate': 1,
#          'Dilinoleoylphosphatidylcholine': 1,
#          'Tetracosanamide': 1,
#          'DL-alpha-Tocopherol': 1,
#          '2-Ethyl-6-methylcyclohexa-2,5-diene-1,4-dione': 1,
#          'Campest-4-en-3-one': 1,
#          '2,5,7,8-tetramethyl-2-[(E)-4,8,12-trimethyltridec-3-enyl]-3,4-dihydrochromen-1-ium-6-ol': 1,
#          'Ethylene dioleamide': 1})

# %%
pd.DataFrame(results)\
    .sort_values("p_Interaction").style
# Out:
# <style type="text/css">
# </style>
# <table id="T_69db5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69db5_level0_col0" class="col_heading level0 col0" >Metabolite</th>
#       <th id="T_69db5_level0_col1" class="col_heading level0 col1" >p_Group</th>
#       <th id="T_69db5_level0_col2" class="col_heading level0 col2" >p_Hour</th>
#       <th id="T_69db5_level0_col3" class="col_heading level0 col3" >p_Interaction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69db5_level0_row0" class="row_heading level0 row0" >20</th>
#       <td id="T_69db5_row0_col0" class="data row0 col0" >O-acetyl-L-carnitine</td>
#       <td id="T_69db5_row0_col1" class="data row0 col1" >0.006181</td>
#       <td id="T_69db5_row0_col2" class="data row0 col2" >0.083946</td>
#       <td id="T_69db5_row0_col3" class="data row0 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_69db5_level0_row1" class="row_heading level0 row1" >78</th>
#       <td id="T_69db5_row1_col0" class="data row1 col0" >6''-O-acetyldaidzin</td>
#       <td id="T_69db5_row1_col1" class="data row1 col1" >0.000076</td>
#       <td id="T_69db5_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_69db5_row1_col3" class="data row1 col3" >0.000001</td>
#     </tr>
#     <tr>
#       <th id="T_69db5_level0_row2" class="row_heading level0 row2" >87</th>
#       <td id="T_69db5_row2_col0" class="data row2 col0" >6''-O-acetylgenistin</td>
#       <td id="T_69db5_row2_col1" class="data row2 col1" >0.000078</td>
#       <td id="T_69db5_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_69db5_row2_col3" class="data row2 col3" >0.000004</td>
#     </tr>
#     <tr>
#       <th id="T_69db5_level0_row3" class="row_heading level0 row3" >122</th>
#       <td id="T_69db5_row3_col0" class="data row3 col0" >Soyasaponin IV</td>
#       <td id="T_69db5_row3_col1" class="data row3 col1" >0.318825</td>
#       <td id="T_69db5_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_69db5_row3_col3" class="data row3 col3" >0.000137</td>
#     </tr>
#     <tr>
#       <th id="T_69db5_level0_row4" class="row_heading level0 row4" >89</th>
#       <td id="T_69db5_row4_col0" class="data row4 col0" >(1-(3-Oxo-2-aza-spiro(4.5)dec-2-ylmethyl)-cyclohexyl)-acetic acid</td>
#       <td id="T_69db5_row4_col1" class="data row4 col1" >0.146589</td>
#       <td id="T_69db5_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_69db5_row4_col3" class="data row4 col3" >0.000139</td>
#     </tr>
#     <tr>
#       <th id="T_69db5_level0_row5" class="row_heading level0 row5" >15</th>
#       <td id="T_69db5_row5_col0" class="data row5 col0" >5-Hydroxymethylfurfural</td>
#       <td id="T_69db5_row5_col1" class="data row5 col1" >0.000030</td>
#       <td id="T_69db5_row5_col2" class="data row5 col2" >0.000444</td>
#       <td id="T_69db5_row5_col3" class="data row5 col3" >0.000169</td>
#     </tr>
#     <tr>
#       <th id="T_69db5_level0_row6" class="row_heading level0 row6" >116</th>
#       <td id="T_69db5_row6_col0" class="data row6 col0" >Oleanolic aldehyde</td>
#       <td id="T_69db5_row6_col1" class="data row6 col1" >0.374116</td>
#       <td id="T_69db5_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_69db5_row6_col3" class="data row6 col3" >0.000206</td>
#     </tr>
#     <tr>
#       <th id="T_69db5_level0_row7" class="row_heading level0 row7" >114</th>
#       <td id="T_69db5_row7_col0" class="data row7 col0" >Soyasaponin II</td>
#       <td id="T_69db5_row7_col1" class="data row7 col1" >0.442880</td>
#       <td id="T_69db5_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_69db5_row7_col3" class="data row7 col3" >0.000345</td>
#     </tr>
#     <tr>
#       <th id="T_69db5_level0_row8" class="row_heading level0 row8" >104</th>
#       <td id="T_69db5_row8_col0" class="data row8 col0" >Sedanolide</td>
#       <td id="T_69db5_row8_col1" class="data row8 col1" >0.231684</td>
#       <td id="T_69db5_row8_col2" class="data row8 col2" >0.000007</td>
#       <td id="T_69db5_row8_col3" class="data row8 col3" >0.000392</td>
#     </tr>
#     <tr>
#       <th id="T_69db5_level0_row9" class="row_heading level0 row9" >119</th>
#       <td id="T_69db5_row9_col0" class="data row9 col0" >Soyasaponin III</td>
#       <td id="T_69db5_row9_col1" class="data row9 col1" >0.572104</td>
#       <td id="T_69db5_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_69db5_row9_col3" class="data row9 col3" >0.000996</td>
#     </tr>
#     <tr>
#       <th id="T_69db5_level0_row10" class="row_heading level0 row10" >68</th>
#       <td id="T_69db5_row10_col0" class="data row10 col0" >L-phenylalanyl-L-leucine</td>
#       <td id="T_69db5_row10_col1" class="data row10 col1" >0.233453</td>
#       <td id="T_69db5_row10_col2" class="data row10 col2" >0.000008</td>
#       <td id="T_69db5_row10_col3" class="data row10 col3" >0.001916</td>
#     </tr>
#     <tr>
#       <th id="T_69db5_level0_row11" class="row_heading level0 row11" >91</th>
#       <td id="T_69db5_row11_col0" class="data row11 col0" > O-octanoylcarnitine</td>
#       <td id="T_69db5_row11_col1" class="data row11 col1" >0.143584</td>
#       <td id="T_69db5_row11_col2" class="data row11 col2" >0.000000</td>
#       <td id="T_69db5_row11_col3" class="data row11 col3" >0.002048</td>
#     </tr>
#     <tr>
#       <th id="T_69db5_level0_row12" class="row_heading level0 row12" >117</th>
#       <td id="T_69db5_row12_col0" class="data row12 col0" >[(2R,4aR,6aR,6aS,6bR,8aR,9S,10S,12aR,14bS)-10-acetyloxy-9-(acetyloxymethyl)-2,4a,6a,6b,9,12a-hexamethyl-4-oxo-3,5,6,6a,7,8,8a,10,11,12,13,14b-dodecahydro-1H-picen-2-yl]methyl acetate</td>
#       <td id="T_69db5_row12_col1" class="data row12 col1" >0.520581</td>
#       <td id="T_69db5_row12_col2" class="data row12 col2" >0.000000</td>
#       <td id="T_69db5_row12_col3" class="data row12 col3" >0.002126</td>
#     </tr>
#     <tr>
#       <th id="T_69db5_level0_row13" class="row_heading level0 row13" >99</th>
#       <td id="T_69db5_row13_col0" class="data row13 col0" >9-(nonanoylamino)nonanoic Acid</td>
#       <td id="T_69db5_row13_col1" class="data row13 col1" >0.173226</td>
#       <td id="T_69db5_row13_col2" class="data row13 col2" >0.000000</td>
#       <td id="T_69db5_row13_col3" class="data row13 col3" >0.002142</td>
#     </tr>
#     <tr>
#       <th id="T_69db5_level0_row14" class="row_heading level0 row14" >115</th>
#       <td id="T_69db5_row14_col0" class="data row14 col0" >Somatotropin (6-13)</td>
#       <td id="T_69db5_row14_col1" class="data row14 col1" >0.788576</td>
#       <td id="T_69db5_row14_col2" class="data row14 col2" >0.000000</td>
#       <td id="T_69db5_row14_col3" class="data row14 col3" >0.003548</td>
#     </tr>
#     <tr>
#       <th id="T_69db5_level0_row15" class="row_heading level0 row15" >8</th>
#       <td id="T_69db5_row15_col0" class="data row15 col0" >2-aminoethyl methyl phosphate</td>
#       <td id="T_69db5_row15_col1" class="data row15 col1" >0.000205</td>
#       <td id="T_69db5_row15_col2" class="data row15 col2" >0.000000</td>
#       <td id="T_69db5_row15_col3" class="data row15 col3" >0.003856</td>
#     </tr>
#     <tr>
#       <th id="T_69db5_level0_row16" class="row_heading level0 row16" >97</th>
#       <td id="T_69db5_row16_col0" class="data row16 col0" >5-Ethyl-2,3-dimethylpyrazine</td>
#       <td id="T_69db5_row16_col1" class="data row16 col1" >0.289064</td>
#       <td id="T_69db5_row16_col2" class="data row16 col2" >0.000015</td>
#       <td id="T_69db5_row16_col3" class="data row16 col3" >0.004478</td>
#     </tr>
#     <tr>
#       <th id="T_69db5_level0_row17" class="row_heading level0 row17" >65</th>
#       <td id="T_69db5_row17_col0" class="data row17 col0" >Daidzin</td>
#       <td id="T_69db5_row17_col1" class="data row17 col1" >0.000433</td>
#       <td id="T_69db5_row17_col2" class="data row17 col2" >0.000000</td>
#       <td id="T_69db5_row17_col3" class="data row17 col3" >0.004629</td>
#     </tr>
#     <tr>
#       <th id="T_69db5_level0_row18" class="row_heading level0 row18" >108</th>
#       <td id="T_69db5_row18_col0" class="data row18 col0" >Soyasaponin I</td>
#       <td id="T_69db5_row18_col1"

# %%
# define metabolite
# metabolite = "Lysinium"

def plot_metabolite_bar(change):
    # get replicate_ids
    metabolite = change["new"]
    replicates = meta.loc[:, "Replicate"].unique().tolist()
    
    metabolite_max = met_table.loc[:, metabolite].max()
    # print(metabolite_max)
    
    fig, axs = plt.subplots(ncols=len(replicates))

    for idx, replicate in enumerate(replicates):
        ax = axs[idx]
        sub_meta = meta.loc[meta["Replicate"] == replicate, :]
        sub_meta = sub_meta.sort_values("Hour")
        sub_met_table = met_table.loc[sub_meta.index.tolist(), [metabolite]]
        

        sns.barplot(data=sub_met_table, y=sub_met_table.index, x=metabolite, ax=ax)
        ax.set_xlabel(replicate)
        
        if metabolite_max > 0:
            ax.set_xlim(0, metabolite_max)
        
        if idx == 0:
            ax.set_ylabel(metabolite)

            newticklabels = [re.sub("C.-", "", yticklabel.get_text()) for yticklabel in ax.get_yticklabels()]
            newticklabels = [re.sub("$", "H", yticklabel) for yticklabel in newticklabels]
            ax.set_yticks(ax.get_yticks())
            ax.set_yticklabels(newticklabels)
        else:
            ax.set_ylabel(None)
            ax.set_yticklabels([])
            
    fig.suptitle(metabolite)
    
    plt.tight_layout()
    plt.show()

metabolites = met_table.columns.tolist()
metabolite_dropdown = widgets.Dropdown(options=sorted(metabolites), description="Metabolites:")
# metabolite_dropdown.observe(plot_metabolite_bar, names="value")

output = widgets.Output()
dashboard = widgets.VBox([metabolite_dropdown, output])

def update_dashboard(change):
    with output:
        clear_output(wait=True)
        plot_metabolite_bar(change)

metabolite_dropdown.observe(update_dashboard, names='value')

display(dashboard)
update_dashboard({'new': metabolite_dropdown.value})
# Out:
# VBox(children=(Dropdown(description='Metabolites:', options=(' 4-Hydroxy Cinnamic Acid', ' Docosanamide', ' Et…
